# %% [markdown]
# # 分类模型特征可视化
#
# 使用 `eli5` 对 sklearn模型的特征重要性可视化分析

# %%
# -*- coding: utf-8 -*-
"""
@author:XuMing(xuming624@qq.com)
@description: 
"""
import sys

sys.path.append('..')
from pytextclassifier import ClassicClassifier
import jieba

tc = ClassicClassifier(model_dir='models/lr-toy', model_name_or_model='lr')
data = [
    ('education', '名师指导托福语法技巧：名词的复数形式'),
    ('education', '中国高考成绩海外认可 是“狼来了”吗？'),
    ('sports', '图文：法网孟菲尔斯苦战进16强 孟菲尔斯怒吼'),
    ('sports', '四川丹棱举行全国长距登山挑战赛 近万人参与'),
    ('sports', '米兰客场8战不败国米10年连胜')
]
tc.train(data)

infer_data = ['高考指导托福语法技巧国际认可',
              '意甲首轮补赛交战记录:米兰客场8战不败国米10年连胜']
predict_label = tc.predict(infer_data)
print(predict_label)  # ['education', 'sports']
# Out:
# 2022-04-12 16:18:28.246 | DEBUG    | pytextclassifier.classic_classifier:__init__:45 - model_name: lr
# 2022-04-12 16:18:28.248 | DEBUG    | pytextclassifier.classic_classifier:__init__:55 - feature_name: tfidf
# 2022-04-12 16:18:28.254 | DEBUG    | pytextclassifier.base_classifier:load_data:29 - loaded data list, X size: 5, y size: 5, num_classes: 2
# 2022-04-12 16:18:28.256 | DEBUG    | pytextclassifier.classic_classifier:train:145 - X_train size: 4, X_test size: 1
# 2022-04-12 16:18:28.260 | DEBUG    | pytextclassifier.classic_classifier:train:147 - X_train sample:
# 1    中国高考成绩海外认可 是“狼来了”吗？
# 4        米兰客场8战不败国米10年连胜
# 0     名师指导托福语法技巧：名词的复数形式
# Name: text, dtype: object
# y_train sample:
# 1    education
# 4       sports
# 0    education
# Name: labels, dtype: object
# 2022-04-12 16:18:28.262 | DEBUG    | pytextclassifier.classic_classifier:train:148 - num_classes:2
# 2022-04-12 16:18:28.265 | DEBUG    | pytextclassifier.classic_classifier:train:151 - X_train_tokens sample:
# ['中国 高考 成绩 海外 认可 狼来了', '米兰 客场 战 不败 国米 10 年 连胜', '名师 指导 托福 语法 技巧 名词 复数 形式']
# 2022-04-12 16:18:28.277 | DEBUG    | pytextclassifier.classic_classifier:train:158 - evaluate, X size: 1, y size: 1, acc: 0.0
# 2022-04-12 16:18:28.282 | INFO     | pytextclassifier.classic_classifier:save_model:227 - Saved model: models/lr-toy/classifier_model.pkl, feature_path: models/lr-toy/classifier_feature.pkl
# (array(['education', 'sports'], dtype=object), [0.5798695481655187, 0.5989415812731275])

# %% [markdown]
# 至此，分类模型训练好了。
#
# `eli5`安装方法：```pip install eli5```
#
# 下面对其模型的feature_weights分析，和预测结果hit_features分析：

# %%
# !pip install eli5
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: eli5 in /Users/xuming/opt/anaconda3/lib/python3.8/site-packages (0.11.0)
# Requirement already satisfied: six in /Users/xuming/opt/anaconda3/lib/python3.8/site-packages (from eli5) (1.15.0)
# Requirement already satisfied: scikit-learn>=0.20 in /Users/xuming/opt/anaconda3/lib/python3.8/site-packages (from eli5) (1.0.2)
# Requirement already satisfied: tabulate>=0.7.7 in /Users/xuming/opt/anaconda3/lib/python3.8/site-packages (from eli5) (0.8.9)
# Requirement already satisfied: jinja2 in /Users/xuming/opt/anaconda3/lib/python3.8/site-packages (from eli5) (2.11.3)
# Requirement already satisfied: attrs>16.0.0 in /Users/xuming/opt/anaconda3/lib/python3.8/site-packages (from eli5) (20.3.0)
# Requirement already satisfied: graphviz in /Users/xuming/opt/anaconda3/lib/python3.8/site-packages (from eli5) (0.17)
# Requirement already satisfied: numpy>=1.9.0 in /Users/xuming/opt/anaconda3/lib/python3.8/site-packages (from eli5) (1.20.1)
# Requirement already satisfied: scipy in /Users/xuming/opt/anaconda3/lib/python3.8/site-packages (from eli5) (1.6.2)
# Requirement already satisfied: joblib>=0.11 in /Users/xuming/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20->eli5) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/xuming/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20->eli5) (2.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/xuming/opt/anaconda3/lib/python3.8/site-packages (from jinja2->eli5) (1.1.1)

# %%
import eli5

eli5.show_weights(tc.model, vec=tc.feature)
# Out:
# /Users/xuming/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=sports
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         不败 国米
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         国米
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         国米 10
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         客场
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         客场 不败
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         10 连胜
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         10
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         连胜
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         不败
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 17 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 15 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         高考 成绩
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         高考
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         认可
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         成绩 海外
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         狼来了
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         海外 认可
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         海外
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         成绩
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         中国 高考
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         中国
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         认可 狼来了
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %%
seg_infer_data = [' '.join(jieba.lcut(i)) for i in infer_data]
eli5.show_prediction(tc.model, seg_infer_data[0], vec=tc.feature,
                     target_names=['education', 'sports'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=education
#
# </b>
#
#
#     (probability <b>0.580</b>, score <b>-0.322</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.322
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 79.34%); opacity: 0.88" title="0.040">高考</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 69.88%); opacity: 0.93" title="0.069">指导</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.104">托福</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.104">语法</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 69.88%); opacity: 0.93" title="0.069">技巧</span><span style="opacity: 0.80"> 国际 </span><span style="background-color: hsl(120, 100.00%, 79.34%); opacity: 0.88" title="0.040">认可</span>
#     </p>

# %%
seg_infer_data = [' '.join(jieba.lcut(i)) for i in infer_data]
eli5.show_prediction(tc.model, seg_infer_data[1], vec=tc.feature)
# Out:
# /Users/xuming/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=sports
#
# </b>
#
#
#     (probability <b>0.599</b>, score <b>0.401</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.401
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">意甲 首轮 补赛 交战 记录 : </span><span style="background-color: hsl(120, 100.00%, 69.88%); opacity: 0.93" title="0.073">米兰</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.109">客场</span><span style="opacity: 0.80"> 8 战 </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.109">不败</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.109">国米</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.109">10</span><span style="opacity: 0.80"> 年 </span><span style="background-color: hsl(120, 100.00%, 69.88%); opacity: 0.93" title="0.073">连胜</span>
#     </p>

# %% [markdown]
# 本节完。
